# %% [markdown]
# EJERCICIO 1
# Id cargando todos los ficheros en vuestro jupyter.
# Si os da error leer el pickle será por la versión de pandas. Podéis guardar el csv como pickle y cargarlo de ahí.

# %%
import pandas as pd
import numpy as np
import pickle

# %%
csv=pd.read_csv("../DATA/quejas.csv",sep=";",encoding="ISO-8859-1")
json=pd.read_json("../DATA/quejas.json")
excel=pd.read_excel("../DATA/quejas2.xlsx")
pickle=pd.read_pickle("../DATA/algas.pickle")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/fk/9dj5qplx5dv2l_dlsz8sf1pw0000gn/T/ipykernel_10709/2662546276.py in <module>
#       2 json=pd.read_json("../DATA/quejas.json")
#       3 excel=pd.read_excel("../DATA/quejas2.xlsx")
# ----> 4 pickle=pd.read_pickle("../DATA/algas.pickle")
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     220                 #  "No module named 'pandas.core.sparse.series'"
#     221                 #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
# --> 222                 return pc.load(handles.handle, encoding=None)
#     223         except UnicodeDecodeError:
#     224             # e.g. can occur for files written in py27; see GH#28645 and GH#31988
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/compat/pickle_compat.py in load(fh, encoding, is_verbose)
#     272         up.is_verbose = is_verbose
#     273
# --> 274         return up.load()
#     275     except (ValueError, TypeError):
#     276         raise
#
# /opt/anaconda3/lib/python3.9/pickle.py in load(self)
#    1210                     raise EOFError
#    1211                 assert isinstance(key, bytes_types)
# -> 1212                 dispatch[key[0]](self)
#    1213         except _Stop as stopinst:
#    1214             return stopinst.value
#
# /opt/anaconda3/lib/python3.9/pickle.py in load_stack_global(self)
#    1535         if type(name) is not str or type(module) is not str:
#    1536             raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1537         self.append(self.find_class(module, name))
#    1538     dispatch[STACK_GLOBAL[0]] = load_stack_global
#    1539
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/compat/pickle_compat.py in find_class(self, module, name)
#     204         key = (module, name)
#     205         module, name = _class_locations_map.get(key, key)
# --> 206         return super().find_class(module, name)
#     207
#     208
#
# /opt/anaconda3/lib/python3.9/pickle.py in find_class(self, module, name)
#    1579         __import__(module, level=0)
#    1580         if self.proto >= 4:
# -> 1581             return _getattribute(sys.modules[module], name)[0]
#    1582         else:
#    1583             return getattr(sys.modules[module], name)
#
# /opt/anaconda3/lib/python3.9/pickle.py in _getattribute(obj, name)
#     329             obj = getattr(obj, subpath)
#     330         except AttributeError:
# --> 331             raise AttributeError("Can't get attribute {!r} on {!r}"
#     332                                  .format(name, obj)) from None
#     333     return obj, parent
#
# AttributeError: Can't get attribute '_unpickle_block' on <module 'pandas._libs.internals' from '/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/internals.cpython-39-darwin.so'>

# %%
csv.to_pickle('../DATA/quejas.pkl')

# %% [markdown]
# EJERCICIO 2
# Para poner el práctica el read_clipboard elegir alguna tabla que os podaís encontrar en google y usad dicho método para traer los datos al jupyter notebook. Una vez que los hayáis cargado, guardad esos datos en los siguientes formatos:
# csv
# excel
# json
# pickle

# %%
df_clipboard = pd.read_clipboard(sep = "\t")
df_clipboard.head(23)
#NO ME SALE EXACTAMENTE EN EL FORMATO (SHAPE) QUE QUIERO, PENDIENTE DE REVISAR
# Out:
#     Profesora                             Alumna  Módulo 1\nEquipo  \
# 0         NaN           Anais denise anna Bonamy                 1
# 1         NaN              María González Dueñas                 1
# 2         NaN           Natalia Martinez Catalan                 1
# 3         NaN               Yadira Gonzalez Lara                 1
# 4         NaN         Ángela Ariana Rosales Caro                 2
# 5         NaN                 Antoanela Mateciuc                 2
# 6         NaN                Chloe Aroca Mendoza                 2
# 7         NaN                        Lara Sancho                 2
# 8         NaN  Lucía García-Cernuda Ruiz de Alda                 2
# 9         NaN                   Ana Delia Torres                 3
# 10        NaN       Diana Laura Romero Feliciano                 3
# 11        NaN                Paula Collado Saura                 3
# 12        NaN        Verónica Bellido San Martín                 3
#
#     Módulo 2\nEquipo  Módulo 3\nEquipo  Módulo 1\nPareja 1 Módulo 1\nPareja 2  \
# 0                  1               NaN                   1                  2
# 1                  2               NaN                   2                  3
# 2                  2               NaN                   1                  1
# 3                  1               NaN                   3                  7
# 4                  3               NaN                   5                  1
# 5                  1               NaN                   7                  5
# 6                  3               NaN                   2                  2
# 7                  3               NaN                   5                  3
# 8                  1               NaN                   6                  7
# 9                  1               NaN                   6                  5
# 10                 2               NaN                   3                  6
# 11                 2               NaN                   7                4/2
# 12                 3               NaN                   4                  6
#
#     Módulo 2\nPareja 1  Módulo 2\nPareja 2  Módulo 3\nPareja 1  \
# 0                    1                 NaN                 NaN
# 1                    3                 NaN                 NaN
# 2                    4                 NaN                 NaN
# 3                    1                 NaN                 NaN
# 4                    5                 NaN                 NaN
# 5                    6                 NaN                 NaN
# 6                    6                 NaN                 NaN
# 7                    2                 NaN                 NaN
# 8                    3                 NaN                 NaN
# 9                    1                 NaN                 NaN
# 10                   2                 NaN                 NaN
# 11                   4                 NaN                 NaN
# 12                   5                 NaN                 NaN
#
#     Módulo 3\nPareja 2
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN

# %%
# guardaar el formato en csv

df_clipboard.to_csv("../DATA/Equiposyparejas.csv")

# %%
# guardar en formato de excel

df_clipboard.to_excel("../DATA/Equiposyparejas.xlsx")

# %%
# guardar en formato json

df_clipboard.to_json("../DATA/Equiposyparejas.json")

# %%
# guardar en formato pickle

df_clipboard.to_pickle("../DATA/Equiposyparejas.pickle")
