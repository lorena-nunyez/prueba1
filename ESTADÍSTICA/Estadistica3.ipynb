# %% [markdown]
# EJERCICIO 1.
# Extraer los siguentes estadísiticos del conjunto de datos para varias de las varibles disponibles:
# Tabla de contingencia
# Coeficiente de correlación de las variables numéricas del dataset.
# Sesgos de alguna de las variables numéricas del dataset.
# Intervalo de confianza de algunas de las variables numéricas del dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st
from scipy.stats import skew

# %%
df = pd.read_csv("../DATA/ds_salaries.csv")
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.describe (include = object)
# Out:
#        experience_level employment_type       job_title salary_currency  \
# count               607             607             607             607
# unique                4               4              50              17
# top                  SE              FT  Data Scientist             USD
# freq                280             588             143             398
#
#        employee_residence company_location company_size
# count                 607              607          607
# unique                 57               50            3
# top                    US               US            M
# freq                  332              355          326

# %% [markdown]
# Tabla de contingencia

# %%
pd.crosstab(df["experience_level"], df["job_title"]).T
# Out:
# experience_level                          EN  EX  MI  SE
# job_title
# 3D Computer Vision Researcher              0   0   1   0
# AI Scientist                               4   0   2   1
# Analytics Engineer                         0   2   0   2
# Applied Data Scientist                     1   0   2   2
# Applied Machine Learning Scientist         1   0   3   0
# BI Data Analyst                            2   1   3   0
# Big Data Architect                         0   0   0   1
# Big Data Engineer                          3   0   3   2
# Business Data Analyst                      2   0   3   0
# Cloud Data Engineer                        0   0   1   1
# Computer Vision Engineer                   3   0   0   3
# Computer Vision Software Engineer          2   0   1   0
# Data Analyst                              12   2  29  54
# Data Analytics Engineer                    1   0   1   2
# Data Analytics Lead                        0   0   0   1
# ...

# %% [markdown]
# Coeficiente de correlación de las variables numéricas del dataset.

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
np.corrcoef(df["work_year"],df["salary_in_usd"])
# Out:
# array([[1.        , 0.17049332],
#        [0.17049332, 1.        ]])

# %%
plt.figure (figsize = (15,8))

fig = sns.heatmap(np.corrcoef(df["work_year"],df["salary_in_usd"]), annot = True)

# %% [markdown]
# Sesgos de alguna de las variables numéricas del dataset.

# %%
skew(df["salary_in_usd"])
#Observamos que tenemos un sesgado positiva con "cola" a la derecha y concentración de datos a la izquierda
# Out:
# 1.6634213360977623

# %%
fig, ax = plt.subplots(figsize = (15,8))
sns.histplot(x = "salary_in_usd", data = df);

media = np.mean(df['salary_in_usd'])
mediana = np.median(df['salary_in_usd'])
plt.axvline(media, color='red')
plt.axvline(mediana, color='orange')
plt.show()

# %% [markdown]
# EJERCICIO 2.
# Interpretación de los resultados.
# Ahora interpreta los resultados obtenidos de los diferentes estadísticos estudiados haciendo hincapié en aspectos interesantes de tus datos y explica lo mejor posible la naturaleza de los mismos.

# %% [markdown]
# Tabla de contingencia:
#
#     Interpretando la tabla podemos ver que la mayor parte de datos obtenidos se concentran en Data Analyst, Data Engineer, Data Scientist, Machine Learning Engineer en los puestos de trabajo con mayor experiencia.
#
# Coeficiente de correlación de las variables numéricas del dataset:
#
#     Hay una correlación positiva en número de años de trabajo,  con el salario percibido en USD, aunque ésta es muy pequeña, casi nula, por lo que no se podría interpretar en todos los casos que a mayor número de años trabajando, mayor salario percibido, sino que el aumento de salario dependerá de otras variables, no vistas en este estudio.
#
# Sesgos de alguna de las variables numéricas del dataset.
#
#     La densidad de datos obtenidos se concentra a la izquierda, teniendo en cuenta la simetría de la gráfica podemos deducir que la mayoría de los salarios se concentran en torno a los 100.000 USD, por lo que al estar sesgada a la derecha todos aquellos salarios que quedan en el extremo de ese lado podríamos considerarlos datos atípicos, o outliers.
